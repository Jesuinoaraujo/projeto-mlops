# %%
import pandas as pd

# Caminho para os dados Silver
silver_path = '../data/silver/nafld_merged.parquet'

# Leitura do arquivo Parquet
df = pd.read_parquet(silver_path, engine='pyarrow')

# Estatísticas Descritivas
print("Estatísticas Descritivas:")
display(df.describe())
# Out:
# Estatísticas Descritivas:
#           Unnamed: 0             id            age           male  \
# count  417672.000000  417672.000000  417672.000000  417672.000000
# mean   214143.217522    8798.526269      68.313440       0.977619
# std    132298.742791    5080.145857       4.455774       0.147920
# min         1.000000       1.000000      18.000000       0.000000
# 25%     98517.750000    4408.000000      69.000000       1.000000
# 50%    213351.500000    8811.000000      69.000000       1.000000
# 75%    329284.250000   13159.000000      69.000000       1.000000
# max    444423.000000   17566.000000      98.000000       1.000000
#
#               weight         height            bmi        case.id  \
# count  417672.000000  417672.000000  417672.000000  417672.000000
# mean       93.774309     179.556870      29.240565    2303.746272
# std         4.811145       2.962964       1.458099    1716.510105
# min        33.400000     123.000000       9.207332       3.000000
# 25%        94.100000     180.000000      29.204650    2017.000000
# 50%        94.100000     180.000000      29.204650    2017.000000
# 75%        94.100000     180.000000      29.204650    2017.000000
# max       181.700000     215.000000      84.395725   17563.000000
#
#               futime         status           days          value
# count  417672.000000  417672.000000  400123.000000  400123.000000
# mean     2729.991814       0.003266    -606.916616      63.768339
# std       329.291237       0.057053    2415.953135      48.455567
# min         7.000000       0.000000   -7651.000000       0.000000
# 25%      2744.000000       0.000000   -2259.000000      40.000000
# 50%      2744.000000       0.000000    -530.000000      51.000000
# 75%      2744.000000       0.000000     987.000000      72.000000
# max      7268.000000       1.000000    7187.000000   13682.000000
