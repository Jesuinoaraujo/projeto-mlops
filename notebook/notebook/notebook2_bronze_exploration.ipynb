# %%
import pandas as pd
import os

# Definir caminho absoluto correto para a pasta bronze
caminho_absoluto_bronze = os.path.abspath("../../data/bronze")

# Carregar dados transformados da camada Bronze
df_bronze1 = pd.read_parquet(os.path.join(caminho_absoluto_bronze, "nafld1.parquet"))
df_bronze2 = pd.read_parquet(os.path.join(caminho_absoluto_bronze, "nafld2.parquet"))

# Exibir os primeiros registros dos dados
print("Bronze NAFLD1:")
print(df_bronze1.head())

print("Bronze NAFLD2:")
print(df_bronze2.head())

# Exibir informações gerais sobre os dados
print("\nInformações sobre Bronze NAFLD1:")
df_bronze1.info()

print("\nInformações sobre Bronze NAFLD2:")
df_bronze2.info()
# Out:
# Bronze NAFLD1:
#    Unnamed: 0  id  age  male  weight  height        bmi  case.id  futime  \
# 0        3631   1   57     0    60.0   163.0  22.690939  10630.0    6261
# 1        8458   2   67     0    70.4   168.0  24.884028  14817.0     624
# 2        6298   3   53     1   105.8   186.0  30.453537      3.0    1783
# 3       15398   4   56     1   109.3   170.0  37.830100   6628.0    3143
# 4       13261   5   68     1     NaN     NaN        NaN   1871.0    1836
#
#    status
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
# Bronze NAFLD2:
#    Unnamed: 0  id  days  test  value
# 0      135077   1  -459   hdl   75.0
# 1      313143   1  -459  chol   75.0
# 2      135078   1   183   hdl   64.0
# 3      313144   1   183  chol   64.0
# 4      135079   1  2030   hdl   74.0
#
# Informações sobre Bronze NAFLD1:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17549 entries, 0 to 17548
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ...
